# %% [markdown]
# # Examine Delight output for desc dc2

# %% [markdown]
# - author : Sylvie Dagoret-Campagne
# - date : March 20th 2021
# - affiliation : IJCLab/IN2P3/CNRS

# %% [markdown]
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
# import os

# %%
import sys
from mpi4py import MPI
import numpy as np
from scipy.interpolate import interp1d
from delight.io import *
from delight.utils import *
from delight.photoz_gp import PhotozGP
from delight.photoz_kernels import Photoz_mean_function, Photoz_kernel
import scipy.stats
import matplotlib.pyplot as plt
import emcee
import corner

# Create a logger object.
logger = logging.getLogger(__name__)
coloredlogs.install(level='DEBUG', logger=logger,fmt='%(asctime)s,%(msecs)03d %(programname)s %(name)s[%(process)d] %(levelname)s %(message)s')

comm = MPI.COMM_WORLD
threadNum = comm.Get_rank()
numThreads = comm.Get_size()

# %%
plt.rcParams["figure.figsize"] = (12,6)
plt.rcParams["axes.labelsize"] = 'xx-large'
plt.rcParams['axes.titlesize'] = 'xx-large'
plt.rcParams['xtick.labelsize']= 'xx-large'
plt.rcParams['ytick.labelsize']= 'xx-large'

# %%
import os

# %%
from pkg_resources import resource_filename

# %%
# !ls tmp/*
# Out:
# tmp/parametersTest.cfg	   tmp/parametersTest_16.cfg  tmp/parametersTest_4.cfg
# tmp/parametersTest_1.cfg   tmp/parametersTest_17.cfg  tmp/parametersTest_5.cfg
# tmp/parametersTest_10.cfg  tmp/parametersTest_18.cfg  tmp/parametersTest_6.cfg
# tmp/parametersTest_11.cfg  tmp/parametersTest_19.cfg  tmp/parametersTest_7.cfg
# tmp/parametersTest_12.cfg  tmp/parametersTest_2.cfg   tmp/parametersTest_8.cfg
# tmp/parametersTest_13.cfg  tmp/parametersTest_20.cfg  tmp/parametersTest_9.cfg
# tmp/parametersTest_14.cfg  tmp/parametersTest_21.cfg
# tmp/parametersTest_15.cfg  tmp/parametersTest_3.cfg
#
# tmp/delight_data:
# galaxies-fluxredshifts.txt	     galaxies-redshiftmetrics_18.txt
# galaxies-fluxredshifts2.txt	     galaxies-redshiftmetrics_19.txt
# galaxies-fluxredshifts2_1.txt	     galaxies-redshiftmetrics_2.txt
# galaxies-fluxredshifts2_10.txt	     galaxies-redshiftmetrics_20.txt
# galaxies-fluxredshifts2_11.txt	     galaxies-redshiftmetrics_21.txt
# galaxies-fluxredshifts2_12.txt	     galaxies-redshiftmetrics_3.txt
# galaxies-fluxredshifts2_13.txt	     galaxies-redshiftmetrics_4.txt
# galaxies-fluxredshifts2_14.txt	     galaxies-redshiftmetrics_5.txt
# galaxies-fluxredshifts2_15.txt	     galaxies-redshiftmetrics_6.txt
# galaxies-fluxredshifts2_16.txt	     galaxies-redshiftmetrics_7.txt
# galaxies-fluxredshifts2_17.txt	     galaxies-redshiftmetrics_8.txt
# galaxies-fluxredshifts2_18.txt	     galaxies-redshiftmetrics_9.txt
# galaxies-fluxredshifts2_19.txt	     galaxies-redshiftpdfs-cww.txt
# galaxies-fluxredshifts2_2.txt	     galaxies-redshiftpdfs-cww_1.txt
# galaxies-fluxredshifts2_20.txt	     galaxies-redshiftpdfs-cww_10.txt
# galaxies-fluxredshifts2_21.txt	     galaxies-redshiftpdfs-cww_11.txt
# galaxies-fluxredshifts2_3.txt	     galaxies-redshiftpdfs-cww_12.txt
# galaxies-fluxredshifts2_4.txt	     galaxies-redshiftpdfs-cww_13.txt
# galaxies-fluxredshifts2_5.txt	     galaxies-redshiftpdfs-cww_14.txt
# galaxies-fluxredshifts2_6.txt	     galaxies-redshiftpdfs-cww_15.txt
# galaxies-fluxredshifts2_7.txt	     galaxies-redshiftpdfs-cww_16.txt
# galaxies-fluxredshifts2_8.txt	     galaxies-redshiftpdfs-cww_17.txt
# galaxies-fluxredshifts2_9.txt	     galaxies-redshiftpdfs-cww_18.txt
# galaxies-gpparams.txt		     galaxies-redshiftpdfs-cww_19.txt
# galaxies-redshiftmetrics-cww.txt     galaxies-redshiftpdfs-cww_2.txt
# galaxies-redshiftmetrics-cww_1.txt   galaxies-redshiftpdfs-cww_20.txt
# galaxies-redshiftmetrics-cww_10.txt  galaxies-redshiftpdfs-cww_21.txt
# galaxies-redshiftmetrics-cww_11.txt  galaxies-redshiftpdfs-cww_3.txt
# galaxies-redshiftmetrics-cww_12.txt  galaxies-redshiftpdfs-cww_4.txt
# galaxies-redshiftmetrics-cww_13.txt  galaxies-redshiftpdfs-cww_5.txt
# galaxies-redshiftmetrics-cww_14.txt  galaxies-redshiftpdfs-cww_6.txt
# galaxies-redshiftmetrics-cww_15.txt  galaxies-redshiftpdfs-cww_7.txt
# galaxies-redshiftmetrics-cww_16.txt  galaxies-redshiftpdfs-cww_8.txt
# galaxies-redshiftmetrics-cww_17.txt  galaxies-redshiftpdfs-cww_9.txt
# galaxies-redshiftmetrics-cww_18.txt  galaxies-redshiftpdfs_1.txt
# galaxies-redshiftmetrics-cww_19.txt  galaxies-redshiftpdfs_10.txt
# galaxies-redshiftmetrics-cww_2.txt   galaxies-redshiftpdfs_11.txt
# galaxies-redshiftmetrics-cww_20.txt  galaxies-redshiftpdfs_12.txt
# galaxies-redshiftmetrics-cww_21.txt  galaxies-redshiftpdfs_13.txt
# galaxies-redshiftmetrics-cww_3.txt   galaxies-redshiftpdfs_14.txt
# galaxies-redshiftmetrics-cww_4.txt   galaxies-redshiftpdfs_15.txt
# galaxies-redshiftmetrics-cww_5.txt   galaxies-redshiftpdfs_16.txt
# galaxies-redshiftmetrics-cww_6.txt   galaxies-redshiftpdfs_17.txt
# galaxies-redshiftmetrics-cww_7.txt   galaxies-redshiftpdfs_18.txt
# galaxies-redshiftmetrics-cww_8.txt   galaxies-redshiftpdfs_19.txt
# galaxies-redshiftmetrics-cww_9.txt   galaxies-redshiftpdfs_2.txt
# galaxies-redshiftmetrics_1.txt	     galaxies-redshiftpdfs_20.txt
# galaxies-redshiftmetrics_10.txt      galaxies-redshiftpdfs_21.txt
# galaxies-redshiftmetrics_11.txt      galaxies-redshiftpdfs_3.txt
# galaxies-redshiftmetrics_12.txt      galaxies-redshiftpdfs_4.txt
# galaxies-redshiftmetrics_13.txt      galaxies-redshiftpdfs_5.txt
# galaxies-redshiftmetrics_14.txt      galaxies-redshiftpdfs_6.txt
# galaxies-redshiftmetrics_15.txt      galaxies-redshiftpdfs_7.txt
# galaxies-redshiftmetrics_16.txt      galaxies-redshiftpdfs_8.txt
# galaxies-redshiftmetrics_17.txt      galaxies-redshiftpdfs_9.txt

# %% [markdown]
# # Definitions and constants

# %%
configfileparamdir="tmp"

# %%
configfilerootname="parametersTest_"

# %%
Nconfigfilenum = 21

# %% [markdown]
# ## Build config parameter file list

# %%
configFileList = []

for idx in np.arange(1,Nconfigfilenum+1):
    configfilename=configfilerootname+str(idx)+".cfg"
    configfullfilename = os.path.join(configfileparamdir,configfilename)
    configFileList.append(configfullfilename)

# %%
configFileList
# Out:
# ['tmp/parametersTest_1.cfg',
#  'tmp/parametersTest_2.cfg',
#  'tmp/parametersTest_3.cfg',
#  'tmp/parametersTest_4.cfg',
#  'tmp/parametersTest_5.cfg',
#  'tmp/parametersTest_6.cfg',
#  'tmp/parametersTest_7.cfg',
#  'tmp/parametersTest_8.cfg',
#  'tmp/parametersTest_9.cfg',
#  'tmp/parametersTest_10.cfg',
#  'tmp/parametersTest_11.cfg',
#  'tmp/parametersTest_12.cfg',
#  'tmp/parametersTest_13.cfg',
#  'tmp/parametersTest_14.cfg',
#  'tmp/parametersTest_15.cfg',
#  'tmp/parametersTest_16.cfg',
#  'tmp/parametersTest_17.cfg',
#  'tmp/parametersTest_18.cfg',
#  'tmp/parametersTest_19.cfg',
#  'tmp/parametersTest_20.cfg',
#  'tmp/parametersTest_21.cfg']

# %% [markdown]
# # Configuration

# %%
idx_sel=15

# %% [markdown]
# ### DESC Delight data

# %%
configdatafilename=configFileList[idx_sel]

# %%
params = parseParamFile(configdatafilename, verbose=True)
# Out:
# 2021-04-03 13:30:56,038 ipykernel_launcher.py, delight.io[265] WARNING Input parameter file:tmp/parametersTest_16.cfg
# 2021-04-03 13:30:56,042 ipykernel_launcher.py, delight.io[265] WARNING Parameters read:
# >  rootDir              ./
# >  bands_directory      /home/ubuntu/.local/lib/python3.8/site-packages/delight/../data/FILTERS
# >  bandNames            lsst_u lsst_g lsst_r lsst_i lsst_z lsst_y
# >  numCoefs             15
# >  bands_verbose        True
# >  bands_debug          True
# >  bands_makeplots      False
# >  templates_directory  /home/ubuntu/.local/lib/python3.8/site-packages/delight/../data/CWW_SEDs
# >  lambdaRef            4500.0
# >  templates_names      El_B2004a Sbc_B2004a Scd_B2004a SB3_B2004a SB2_B2004a Im_B2004a ssp_25Myr_z008 ssp_5Myr_z008
# >  p_t                  [0.27   0.26   0.25   0.069  0.021  0.11   0.0061 0.0079]
# >  p_z_t                [0.23 0.39 0.33 0.31 1.1  0.34 1.2  0.14]
# >  templates_verbose    False
# >  templates_debug      False
# >  training_numChunks   1
# >  training_paramFile   ./tmp/delight_data/galaxies-gpparams.txt
# >  training_catFile     ./tmp/delight_data/galaxies-fluxredshifts.txt
# >  training_referenceBand lsst_i
# >  training_bandOrder   lsst_u lsst_u_var lsst_g lsst_g_var lsst_r lsst_r_var lsst_i lsst_i_var lsst_z lsst_z_var lsst_y lsst_y_var redshift
# >  training_extraFracFluxError 0.0001
# >  training_crossValidate False
# >  training_CV_bandOrder _ _ _ _ lsst_r lsst_r_var _ _ _ _ _ _
# >  training_CVfile      ./tmp/delight_data/galaxies-gpCV.txt
# >  trainingFile         ./tmp/delight_data/galaxies-fluxredshifts.txt
# >  targetFile           ./tmp/delight_data/galaxies-fluxredshifts2_16.txt
# >  numObjects           1000
# >  noiseLevel           0.03
# >  target_extraFracFluxError 0.0001
# >  target_catFile       ./tmp/delight_data/galaxies-fluxredshifts2_16.txt
# >  target_bandOrder     lsst_u lsst_u_var lsst_g lsst_g_var lsst_r lsst_r_var lsst_i lsst_i_var lsst_z lsst_z_var lsst_y lsst_y_var redshift
# >  target_referenceBand lsst_r
# >  compressIndicesFile  ./tmp/delight_data/galaxies-compressionIndices_16.txt
# >  compressMargLikFile  ./tmp/delight_data/galaxies-compressionMargLikes_16.txt
# >  compressionFilesFound False
# >  Ncompress            10
# >  useCompression       False
# >  redshiftpdfFile      ./tmp/delight_data/galaxies-redshiftpdfs_16.txt
# >  redshiftpdfFileComp  ./tmp/delight_data/galaxies-redshiftpdfs-comp_16.txt
# >  redshiftpdfFileTemp  ./tmp/delight_data/galaxies-redshiftpdfs-cww_16.txt
# >  metricsFile          ./tmp/delight_data/galaxies-redshiftmetrics_16.txt
# >  metricsFileTemp      ./tmp/delight_data/galaxies-redshiftmetrics-cww_16.txt
# >  zPriorSigma          0.2
# >  ellPriorSigma        0.5
# >  fluxLuminosityNorm   1.0
# >  alpha_C              1000.0
# >  alpha_L              100.0
# >  V_C                  0.1
# >  V_L                  0.1
# >  redshiftMin          0.01
# >  redshiftMax          3.01
# >  redshiftBinSize      0.01
# >  redshiftNumBinsGPpred 300
# >  redshiftDisBinSize   0.2
# >  lines_pos            6500.0 5002.26 3732.22
# >  lines_width          20.0 20.0 20.0 20.0
# >  confidenceLevels     0.1 0.5 0.68 0.95

# %% [markdown]
# # Analyse

# %%
DL = approx_DL()
redshiftDistGrid, redshiftGrid, redshiftGridGP = createGrids(params)

# %%
bandCoefAmplitudes, bandCoefPositions, bandCoefWidths, norms = readBandCoefficients(params)
bandNames = params['bandNames']
numBands, numCoefs = bandCoefAmplitudes.shape
fluxredshifts = np.loadtxt(params['target_catFile'])
fluxredshifts_train = np.loadtxt(params['training_catFile'])
bandIndices, bandNames, bandColumns, bandVarColumns, redshiftColumn,\
            refBandColumn = readColumnPositions(params, prefix='target_')
redshiftDistGrid, redshiftGrid, redshiftGridGP = createGrids(params)
dir_seds = params['templates_directory']
dir_filters = params['bands_directory']
lambdaRef = params['lambdaRef']
sed_names = params['templates_names']
nt = len(sed_names)
f_mod = np.zeros((redshiftGrid.size, nt, len(params['bandNames'])))
for t, sed_name in enumerate(sed_names):
    f_mod[:, t, :] = np.loadtxt(dir_seds + '/' + sed_name + '_fluxredshiftmod.txt')

# %% [markdown]
# ## Analyze the outputs

# %%
all_metricscww = []
all_metrics = []
all_pdfatZ_cww = []
all_pdfatZ = []
for idx in np.arange(0,Nconfigfilenum):
    configdatafilename=configFileList[idx]
    
    params = parseParamFile(configdatafilename, verbose=False)
    
    DL = approx_DL()
    redshiftDistGrid, redshiftGrid, redshiftGridGP = createGrids(params)
    
    
    # Load the PDF files
    metricscww = np.loadtxt(params['metricsFile'])
    metrics = np.loadtxt(params['metricsFileTemp'])
    
    all_metricscww.append(metricscww)
    all_metrics.append(metrics)
    
    # Those of the indices of the true, mean, stdev, map, and map_std redshifts.
    i_zt, i_zm, i_std_zm, i_zmap, i_std_zmap = 0, 1, 2, 3, 4
    i_ze = i_zm
    i_std_ze = i_std_zm

    pdfs = np.loadtxt(params['redshiftpdfFile'])
    pdfs_cww = np.loadtxt(params['redshiftpdfFileTemp'])
    pdfatZ_cww = metricscww[:, 5] / pdfs_cww.max(axis=1)
    pdfatZ = metrics[:, 5] / pdfs.max(axis=1)
    nobj = pdfatZ.size
    #pdfs /= pdfs.max(axis=1)[:, None]
    #pdfs_cww /= pdfs_cww.max(axis=1)[:, None]
    pdfs /= np.trapz(pdfs, x=redshiftGrid, axis=1)[:, None]
    pdfs_cww /= np.trapz(pdfs_cww, x=redshiftGrid, axis=1)[:, None]
    
    all_pdfatZ_cww.append( pdfatZ_cww)
    all_pdfatZ.append(pdfatZ)

# %%
metricscww_stack=np.vstack(all_metricscww)
metrics_stack=np.vstack(all_metrics)

# %%
pdfatZ_cww_stack=np.concatenate(all_pdfatZ_cww)
pdfatZ_stack=np.concatenate(all_pdfatZ)

# %%
# Load the PDF files
metricscww = np.loadtxt(params['metricsFile'])
metrics = np.loadtxt(params['metricsFileTemp'])
# Those of the indices of the true, mean, stdev, map, and map_std redshifts.
i_zt, i_zm, i_std_zm, i_zmap, i_std_zmap = 0, 1, 2, 3, 4
i_ze = i_zm
i_std_ze = i_std_zm

pdfs = np.loadtxt(params['redshiftpdfFile'])
pdfs_cww = np.loadtxt(params['redshiftpdfFileTemp'])
pdfatZ_cww = metricscww[:, 5] / pdfs_cww.max(axis=1)
pdfatZ = metrics[:, 5] / pdfs.max(axis=1)
nobj = pdfatZ.size
#pdfs /= pdfs.max(axis=1)[:, None]
#pdfs_cww /= pdfs_cww.max(axis=1)[:, None]
pdfs /= np.trapz(pdfs, x=redshiftGrid, axis=1)[:, None]
pdfs_cww /= np.trapz(pdfs_cww, x=redshiftGrid, axis=1)[:, None]

# %%
ncol = 4
fig, axs = plt.subplots(5, ncol, figsize=(12, 12), sharex=False, sharey=False)
axs = axs.ravel()
z = fluxredshifts[:, redshiftColumn]
sel = np.random.choice(nobj, axs.size, replace=False)
lw = 2
for ik in range(axs.size):
    k = sel[ik]
    print(k, end=" ")
    axs[ik].plot(redshiftGrid, pdfs_cww[k, :],lw=lw,color='b' ,label='Standard template fitting')# c="#2ecc71", 
    axs[ik].plot(redshiftGrid, pdfs[k, :], lw=lw, color="r",label='New method')  #, c="#3498db"
    axs[ik].axvline(fluxredshifts[k, redshiftColumn], c="k", lw=1, label=r'Spec-$z$')
    ymax = np.max(np.concatenate((pdfs[k, :], pdfs_cww[k, :])))
    axs[ik].set_ylim([0, ymax*1.2])
    axs[ik].set_xlim([0, 3.1])
    axs[ik].set_yticks([])
    axs[ik].set_xticks([0.0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5])
for i in range(ncol):
    axs[-i-1].set_xlabel('Redshift', fontsize=10)
axs[0].legend(ncol=3, frameon=False, loc='upper left', bbox_to_anchor=(0.0, 1.4))
fig.tight_layout()
fig.subplots_adjust(wspace=0.1, hspace=0.1, top=0.96)
# Out:
# 284 76 48 203 224 10 142 170 167 99 98 121 68 242 47 177 161 116 8 18

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))
zmax = 3
rr = [[0, zmax], [0, zmax]]
nbins = 30
h = axs[0, 0].hist2d(metricscww_stack[:, i_zt], metricscww_stack[:, i_zm], nbins, cmap='Greys', range=rr)
hmin, hmax = np.min(h[0]), np.max(h[0])
axs[0, 0].set_title('CWW z mean')
axs[0, 1].hist2d(metricscww_stack[:, i_zt], metricscww_stack[:, i_zmap], nbins, cmap='Greys', range=rr, vmax=hmax)
axs[0, 1].set_title('CWW z map')
axs[1, 0].hist2d(metrics_stack[:, i_zt], metrics_stack[:, i_zm], nbins, cmap='Greys', range=rr, vmax=hmax)
axs[1, 0].set_title('GP z mean')
axs[1, 1].hist2d(metrics_stack[:, i_zt], metrics_stack[:, i_zmap], nbins, cmap='Greys', range=rr, vmax=hmax)
axs[1, 1].set_title('GP z map')
axs[0, 0].plot([0, zmax], [0, zmax], c='k')
axs[0, 1].plot([0, zmax], [0, zmax], c='k')
axs[1, 0].plot([0, zmax], [0, zmax], c='k')
axs[1, 1].plot([0, zmax], [0, zmax], c='k')
fig.tight_layout()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
chi2s = ((metrics[:, i_zt] - metrics[:, i_ze])/metrics[:, i_std_ze])**2

axs[0].errorbar(metrics_stack[:, i_zt], metrics_stack[:, i_ze], yerr=metrics_stack[:, i_std_ze], fmt='o', markersize=5, capsize=0)
axs[1].errorbar(metricscww_stack[:, i_zt], metricscww_stack[:, i_ze], yerr=metricscww_stack[:, i_std_ze], fmt='o', markersize=5, capsize=0)
axs[0].plot([0, zmax], [0, zmax], 'k')
axs[1].plot([0, zmax], [0, zmax], 'k')
axs[0].set_xlim([0, zmax])
axs[1].set_xlim([0, zmax])
axs[0].set_ylim([0, zmax])
axs[1].set_ylim([0, zmax])
axs[0].set_title('New method')
axs[1].set_title('Standard template fitting')

fig.tight_layout()

# %%
fig, axs = plt.subplots(1, 2, figsize=(13, 6))
chi2s = ((metrics[:, i_zt] - metrics[:, i_ze])/metrics[:, i_std_ze])**2

axs[1].errorbar(metrics_stack[:, i_zt], metrics_stack[:, i_ze], yerr=metrics_stack[:, i_std_ze], fmt='o', markersize=5, color="r",capsize=0)
axs[0].errorbar(metricscww_stack[:, i_zt], metricscww_stack[:, i_ze], yerr=metricscww_stack[:, i_std_ze], fmt='o',color="b" ,markersize=5, capsize=0)
axs[0].plot([0, zmax], [0, zmax], 'k')
axs[1].plot([0, zmax], [0, zmax], 'k')
axs[0].set_xlim([0, zmax])
axs[1].set_xlim([0, zmax])
axs[0].set_ylim([0, zmax])
axs[1].set_ylim([0, zmax])
axs[1].set_title('Gaussian Processes')
axs[0].set_title('Standard template fitting')

axs[0].set_xlabel('Spec-$z$')
axs[0].set_ylabel('Photo-$z$')
axs[1].set_xlabel('Spec-$z$')
axs[1].set_ylabel('Photo-$z$')

fig.tight_layout()

# %%
cmap = "coolwarm_r"
vmin = 0.0
alpha = 0.9
s = 5
fig, axs = plt.subplots(1, 2, figsize=(12, 4.5))
vs = axs[0].scatter(metricscww_stack[:, i_zt], metricscww_stack[:, i_zmap], 
                    s=s, c=pdfatZ_cww_stack, cmap=cmap, linewidth=0, vmin=vmin, alpha=alpha)
vs = axs[1].scatter(metrics_stack[:, i_zt], metrics_stack[:, i_zmap], 
                    s=s, c=pdfatZ_stack, cmap=cmap, linewidth=0, vmin=vmin, alpha=alpha)
clb = plt.colorbar(vs, ax=axs.ravel().tolist())
clb.set_label('Normalized probability at spec-$z$')
for i in range(2):
    axs[i].plot([0, zmax], [0, zmax], c='k', lw=1, zorder=0, alpha=1)
    axs[i].set_ylim([0, zmax])
    axs[i].set_xlim([0, zmax])
    axs[i].set_xlabel('Spec-$z$')
axs[0].set_ylabel('MAP photo-$z$')

axs[0].set_title('Standard template fitting')
axs[1].set_title('Gaussian Processes')
# Out:
# Text(0.5, 1.0, 'New method')

# %% [markdown]
# ## Conclusion
# Don't be too harsh with the results of the standard template fitting or the new methods since both have a lot of parameters which can be optimized!
#
# If the results above made sense, i.e. the redshifts are reasonnable for both methods on the mock data, then you can start modifying the parameter files and creating catalog files containing actual data! I recommend using less than 20k galaxies for training, and 1000 or 10k galaxies for the delight-apply script at the moment. Future updates will address this issue.
